# %%
while True:
    user_input = input("PLease ask a question")
    if user_input.lower() == "quit":
        print("Bye Bye")
        break
    else:
        print(f"add '{user_input}'")

# %%
i=0
while i<10:
    print (i)
    i+=1

# %%
question = input("Enter your question")
print(f"{question}")

# %%
name= "Sandhya"
score = 100
print(f"{name} scored 1{score}% in exam")
print(f"{name}")

# %%
print ("Hello Sandhya's World")
